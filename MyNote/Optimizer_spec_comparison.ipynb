# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adam, Adagrad, RMSprop

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

x_train = x_train.astype(np.float32)/255.0
x_test = x_test.astype(np.float32)/255.0

y_train = tf.keras.utils.to_categorical(y_train, 10) # transform into one-hot encoding.
y_test = tf.keras.utils.to_categorical(y_test, 10) # tf.keras.utils.to_categorical(y, num_classes=None, dtype='float32')

n_input = 784
n_hidden1 = 1024
n_hidden2 = 512
n_hidden3 = 512
n_hidden4 = 512
n_output = 10

batch_size = 256
n_epoch = 50
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 6s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
def build_model():
    model=Sequential()
    model.add(Dense(units=n_hidden1, activation='relu', input_shape=(n_input,)))
    model.add(Dense(units=n_hidden2, activation='relu'))
    model.add(Dense(units=n_hidden3, activation='relu'))
    model.add(Dense(units=n_hidden4, activation='relu'))
    model.add(Dense(units=n_output, activation='softmax'))
    return model

# %% [markdown]
# SGD Model

# %%
dmlp_sgd = build_model()
dmlp_sgd.compile(loss='categorical_crossentropy', optimizer=SGD(), metrics=['accuracy']) #optimizer = SGD()
hist_sgd = dmlp_sgd.fit(x_train, y_train, batch_size=batch_size, epochs=n_epoch, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 2024-12-22 20:30:39.607947: I external/local_xla/xla/service/service.cc:168] XLA service 0x75abe0b29940 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-22 20:30:39.607970: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2024-12-22 20:30:39.618567: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734867039.658216    9793 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 235/235 - 1s - loss: 1.4025 - accuracy: 0.6102 - val_loss: 0.8479 - val_accuracy: 0.7086 - 1s/epoch - 6ms/step
# Epoch 2/50
# 235/235 - 0s - loss: 0.7199 - accuracy: 0.7604 - val_loss: 0.6676 - val_accuracy: 0.7755 - 421ms/epoch - 2ms/step
# Epoch 3/50
# 235/235 - 0s - loss: 0.5997 - accuracy: 0.7973 - val_loss: 0.6032 - val_accuracy: 0.7872 - 427ms/epoch - 2ms/step
# Epoch 4/50
# 235/235 - 0s - loss: 0.5469 - accuracy: 0.8100 - val_loss: 0.5774 - val_accuracy: 0.7969 - 422ms/epoch - 2ms/step
# Epoch 5/50
# 235/235 - 0s - loss: 0.5086 - accuracy: 0.8248 - val_loss: 0.5313 - val_accuracy: 0.8100 - 420ms/epoch - 2ms/step
# Epoch 6/50
# 235/235 - 0s - loss: 0.4838 - accuracy: 0.8317 - val_loss: 0.5017 - val_accuracy: 0.8225 - 411ms/epoch - 2ms/step
# Epoch 7/50
# 235/235 - 0s - loss: 0.4720 - accuracy: 0.8343 - val_loss: 0.5070 - val_accuracy: 0.8241 - 417ms/epoch - 2ms/step
# Epoch 8/50
# 235/235 - 0s - loss: 0.4539 - accuracy: 0.8418 - val_loss: 0.4898 - val_accuracy: 0.8307 - 430ms/epoch - 2ms/step
# Epoch 9/50
# 235/235 - 0s - loss: 0.4430 - accuracy: 0.8456 - val_loss: 0.4971 - val_accuracy: 0.8281 - 420ms/epoch - 2ms/step
# Epoch 10/50
# 235/235 - 0s - loss: 0.4339 - accuracy: 0.8484 - val_loss: 0.4902 - val_accuracy: 0.8284 - 417ms/epoch - 2ms/step
# Epoch 11/50
# 235/235 - 0s - loss: 0.4258 - accuracy: 0.8509 - val_loss: 0.4537 - val_accuracy: 0.8415 - 417ms/epoch - 2ms/step
# Epoch 12/50
# 235/235 - 0s - loss: 0.4168 - accuracy: 0.8543 - val_loss: 0.4540 - val_accuracy: 0.8419 - 420ms/epoch - 2ms/step
# Epoch 13/50
# 235/235 - 0s - loss: 0.4071 - accuracy: 0.8575 - val_loss: 0.4424 - val_accuracy: 0.8462 - 426ms/epoch - 2ms/step
# Epoch 14/50
# 235/235 - 0s - loss: 0.4018 - accuracy: 0.8596 - val_loss: 0.4520 - val_accuracy: 0.8397 - 420ms/epoch - 2ms/step
# Epoch 15/50
# 235/235 - 0s - loss: 0.3961 - accuracy: 0.8618 - val_loss: 0.4257 - val_accuracy: 0.8516 - 421ms/epoch - 2ms/step
# Epoch 16/50
# 235/235 - 0s - loss: 0.3889 - accuracy: 0.8637 - val_loss: 0.5229 - val_accuracy: 0.8017 - 419ms/epoch - 2ms/step
# Epoch 17/50
# 235/235 - 0s - loss: 0.3838 - accuracy: 0.8642 - val_loss: 0.4491 - val_accuracy: 0.8401 - 410ms/epoch - 2ms/step
# Epoch 18/50
# 235/235 - 0s - loss: 0.3807 - accuracy: 0.8663 - val_loss: 0.4179 - val_accuracy: 0.8538 - 422ms/epoch - 2ms/step
# Epoch 19/50
# 235/235 - 0s - loss: 0.3727 - accuracy: 0.8690 - val_loss: 0.4806 - val_accuracy: 0.8202 - 438ms/epoch - 2ms/step
# Epoch 20/50
# 235/235 - 0s - loss: 0.3684 - accuracy: 0.8704 - val_loss: 0.4127 - val_accuracy: 0.8571 - 426ms/epoch - 2ms/step
# Epoch 21/50
# 235/235 - 0s - loss: 0.3655 - accuracy: 0.8704 - val_loss: 0.5013 - val_accuracy: 0.8310 - 457ms/epoch - 2ms/step
# Epoch 22/50
# 235/235 - 0s - loss: 0.3610 - accuracy: 0.8729 - val_loss: 0.4247 - val_accuracy: 0.8492 - 435ms/epoch - 2ms/step
# Epoch 23/50
# 235/235 - 0s - loss: 0.3581 - accuracy: 0.8738 - val_loss: 0.4084 - val_accuracy: 0.8534 - 449ms/epoch - 2ms/step
# Epoch 24/50
# 235/235 - 0s - loss: 0.3543 - accuracy: 0.8740 - val_loss: 0.4190 - val_accuracy: 0.8535 - 432ms/epoch - 2ms/step
# Epoch 25/50
# 235/235 - 0s - loss: 0.3496 - accuracy: 0.8757 - val_loss: 0.4161 - val_accuracy: 0.8519 - 420ms/epoch - 2ms/step
# Epoch 26/50
# 235/235 - 0s - loss: 0.3483 - accuracy: 0.8760 - val_loss: 0.6234 - val_accuracy: 0.7827 - 423ms/epoch - 2ms/step
# Epoch 27/50
# 235/235 - 0s - loss: 0.3417 - accuracy: 0.8790 - val_loss: 0.3967 - val_accuracy: 0.8596 - 418ms/epoch - 2ms/step
# Epoch 28/50
# 235/235 - 0s - loss: 0.3403 - accuracy: 0.8787 - val_loss: 0.3826 - val_accuracy: 0.8658 - 417ms/epoch - 2ms/step
# Epoch 29/50
# 235/235 - 0s - loss: 0.3359 - accuracy: 0.8819 - val_loss: 0.5296 - val_accuracy: 0.8067 - 407ms/epoch - 2ms/step
# Epoch 30/50
# 235/235 - 0s - loss: 0.3339 - accuracy: 0.8817 - val_loss: 0.4101 - val_accuracy: 0.8541 - 421ms/epoch - 2ms/step
# Epoch 31/50
# 235/235 - 0s - loss: 0.3298 - accuracy: 0.8828 - val_loss: 0.3977 - val_accuracy: 0.8578 - 428ms/epoch - 2ms/step
# Epoch 32/50
# 235/235 - 0s - loss: 0.3262 - accuracy: 0.8845 - val_loss: 0.3863 - val_accuracy: 0.8632 - 434ms/epoch - 2ms/step
# Epoch 33/50
# 235/235 - 0s - loss: 0.3236 - accuracy: 0.8855 - val_loss: 0.3801 - val_accuracy: 0.8659 - 425ms/epoch - 2ms/step
# Epoch 34/50
# 235/235 - 0s - loss: 0.3208 - accuracy: 0.8856 - val_loss: 0.3801 - val_accuracy: 0.8672 - 414ms/epoch - 2ms/step
# Epoch 35/50
# 235/235 - 0s - loss: 0.3204 - accuracy: 0.8859 - val_loss: 0.4231 - val_accuracy: 0.8521 - 434ms/epoch - 2ms/step
# Epoch 36/50
# 235/235 - 0s - loss: 0.3150 - accuracy: 0.8883 - val_loss: 0.3904 - val_accuracy: 0.8629 - 428ms/epoch - 2ms/step
# Epoch 37/50
# 235/235 - 0s - loss: 0.3122 - accuracy: 0.8892 - val_loss: 0.4123 - val_accuracy: 0.8530 - 438ms/epoch - 2ms/step
# Epoch 38/50
# 235/235 - 0s - loss: 0.3085 - accuracy: 0.8908 - val_loss: 0.3599 - val_accuracy: 0.8744 - 414ms/epoch - 2ms/step
# Epoch 39/50
# 235/235 - 0s - loss: 0.3080 - accuracy: 0.8901 - val_loss: 0.3598 - val_accuracy: 0.8709 - 431ms/epoch - 2ms/step
# Epoch 40/50
# 235/235 - 0s - loss: 0.3050 - accuracy: 0.8902 - val_loss: 0.3673 - val_accuracy: 0.8700 - 427ms/epoch - 2ms/step
# Epoch 41/50
# 235/235 - 0s - loss: 0.3024 - accuracy: 0.8923 - val_loss: 0.3730 - val_accuracy: 0.8661 - 431ms/epoch - 2ms/step
# Epoch 42/50
# 235/235 - 0s - loss: 0.2999 - accuracy: 0.8937 - val_loss: 0.3972 - val_accuracy: 0.8614 - 423ms/epoch - 2ms/step
# Epoch 43/50
# 235/235 - 0s - loss: 0.2993 - accuracy: 0.8928 - val_loss: 0.3663 - val_accuracy: 0.8679 - 430ms/epoch - 2ms/step
# Epoch 44/50
# 235/235 - 0s - loss: 0.2942 - accuracy: 0.8945 - val_loss: 0.3572 - val_accuracy: 0.8719 - 412ms/epoch - 2ms/step
# Epoch 45/50
# 235/235 - 0s - loss: 0.2939 - accuracy: 0.8947 - val_loss: 0.3698 - val_accuracy: 0.8663 - 423ms/epoch - 2ms/step
# Epoch 46/50
# 235/235 - 0s - loss: 0.2898 - accuracy: 0.8966 - val_loss: 0.4075 - val_accuracy: 0.8513 - 440ms/epoch - 2ms/step
# Epoch 47/50
# 235/235 - 0s - loss: 0.2893 - accuracy: 0.8965 - val_loss: 0.3508 - val_accuracy: 0.8737 - 424ms/epoch - 2ms/step
# Epoch 48/50
# 235/235 - 0s - loss: 0.2851 - accuracy: 0.8979 - val_loss: 0.3627 - val_accuracy: 0.8675 - 431ms/epoch - 2ms/step
# Epoch 49/50
# 235/235 - 0s - loss: 0.2839 - accuracy: 0.8986 - val_loss: 0.3677 - val_accuracy: 0.8676 - 428ms/epoch - 2ms/step
# Epoch 50/50
# 235/235 - 0s - loss: 0.2797 - accuracy: 0.8993 - val_loss: 0.3430 - val_accuracy: 0.8782 - 426ms/epoch - 2ms/step

# %% [markdown]
# Adam Model

# %%
dmlp_adam = build_model()
dmlp_adam.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
hist_adam = dmlp_adam.fit(x_train, y_train, batch_size=batch_size, epochs=n_epoch, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 2024-12-22 20:33:12.123194: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 235/235 - 1s - loss: 0.5053 - accuracy: 0.8164 - val_loss: 0.4099 - val_accuracy: 0.8531 - 1s/epoch - 6ms/step
# Epoch 2/50
# 235/235 - 0s - loss: 0.3540 - accuracy: 0.8707 - val_loss: 0.3884 - val_accuracy: 0.8595 - 443ms/epoch - 2ms/step
# Epoch 3/50
# 235/235 - 0s - loss: 0.3192 - accuracy: 0.8825 - val_loss: 0.3583 - val_accuracy: 0.8714 - 444ms/epoch - 2ms/step
# Epoch 4/50
# 235/235 - 0s - loss: 0.2954 - accuracy: 0.8907 - val_loss: 0.3879 - val_accuracy: 0.8667 - 448ms/epoch - 2ms/step
# Epoch 5/50
# 235/235 - 0s - loss: 0.2770 - accuracy: 0.8960 - val_loss: 0.3317 - val_accuracy: 0.8778 - 440ms/epoch - 2ms/step
# Epoch 6/50
# 235/235 - 0s - loss: 0.2588 - accuracy: 0.9027 - val_loss: 0.3673 - val_accuracy: 0.8759 - 444ms/epoch - 2ms/step
# Epoch 7/50
# 235/235 - 0s - loss: 0.2485 - accuracy: 0.9059 - val_loss: 0.3394 - val_accuracy: 0.8853 - 445ms/epoch - 2ms/step
# Epoch 8/50
# 235/235 - 0s - loss: 0.2408 - accuracy: 0.9089 - val_loss: 0.3440 - val_accuracy: 0.8790 - 454ms/epoch - 2ms/step
# Epoch 9/50
# 235/235 - 0s - loss: 0.2291 - accuracy: 0.9130 - val_loss: 0.3101 - val_accuracy: 0.8881 - 443ms/epoch - 2ms/step
# Epoch 10/50
# 235/235 - 0s - loss: 0.2181 - accuracy: 0.9156 - val_loss: 0.3304 - val_accuracy: 0.8816 - 446ms/epoch - 2ms/step
# Epoch 11/50
# 235/235 - 0s - loss: 0.2111 - accuracy: 0.9200 - val_loss: 0.3515 - val_accuracy: 0.8870 - 441ms/epoch - 2ms/step
# Epoch 12/50
# 235/235 - 0s - loss: 0.2003 - accuracy: 0.9232 - val_loss: 0.3632 - val_accuracy: 0.8844 - 436ms/epoch - 2ms/step
# Epoch 13/50
# 235/235 - 0s - loss: 0.1972 - accuracy: 0.9245 - val_loss: 0.3363 - val_accuracy: 0.8859 - 456ms/epoch - 2ms/step
# Epoch 14/50
# 235/235 - 0s - loss: 0.1896 - accuracy: 0.9283 - val_loss: 0.3264 - val_accuracy: 0.8908 - 450ms/epoch - 2ms/step
# Epoch 15/50
# 235/235 - 0s - loss: 0.1808 - accuracy: 0.9310 - val_loss: 0.3619 - val_accuracy: 0.8864 - 448ms/epoch - 2ms/step
# Epoch 16/50
# 235/235 - 0s - loss: 0.1762 - accuracy: 0.9319 - val_loss: 0.3562 - val_accuracy: 0.8860 - 464ms/epoch - 2ms/step
# Epoch 17/50
# 235/235 - 0s - loss: 0.1640 - accuracy: 0.9359 - val_loss: 0.3460 - val_accuracy: 0.8958 - 445ms/epoch - 2ms/step
# Epoch 18/50
# 235/235 - 0s - loss: 0.1621 - accuracy: 0.9377 - val_loss: 0.3365 - val_accuracy: 0.8937 - 443ms/epoch - 2ms/step
# Epoch 19/50
# 235/235 - 0s - loss: 0.1555 - accuracy: 0.9405 - val_loss: 0.3325 - val_accuracy: 0.8971 - 441ms/epoch - 2ms/step
# Epoch 20/50
# 235/235 - 0s - loss: 0.1528 - accuracy: 0.9405 - val_loss: 0.3515 - val_accuracy: 0.8928 - 445ms/epoch - 2ms/step
# Epoch 21/50
# 235/235 - 0s - loss: 0.1437 - accuracy: 0.9446 - val_loss: 0.3531 - val_accuracy: 0.8960 - 449ms/epoch - 2ms/step
# Epoch 22/50
# 235/235 - 0s - loss: 0.1386 - accuracy: 0.9454 - val_loss: 0.3828 - val_accuracy: 0.8883 - 442ms/epoch - 2ms/step
# Epoch 23/50
# 235/235 - 0s - loss: 0.1361 - accuracy: 0.9472 - val_loss: 0.4416 - val_accuracy: 0.8906 - 444ms/epoch - 2ms/step
# Epoch 24/50
# 235/235 - 0s - loss: 0.1286 - accuracy: 0.9499 - val_loss: 0.3993 - val_accuracy: 0.8988 - 443ms/epoch - 2ms/step
# Epoch 25/50
# 235/235 - 0s - loss: 0.1297 - accuracy: 0.9493 - val_loss: 0.4031 - val_accuracy: 0.8913 - 429ms/epoch - 2ms/step
# Epoch 26/50
# 235/235 - 0s - loss: 0.1243 - accuracy: 0.9512 - val_loss: 0.4368 - val_accuracy: 0.8934 - 438ms/epoch - 2ms/step
# Epoch 27/50
# 235/235 - 0s - loss: 0.1152 - accuracy: 0.9542 - val_loss: 0.4280 - val_accuracy: 0.8935 - 437ms/epoch - 2ms/step
# Epoch 28/50
# 235/235 - 0s - loss: 0.1141 - accuracy: 0.9550 - val_loss: 0.4162 - val_accuracy: 0.8953 - 444ms/epoch - 2ms/step
# Epoch 29/50
# 235/235 - 0s - loss: 0.1069 - accuracy: 0.9572 - val_loss: 0.4324 - val_accuracy: 0.8950 - 447ms/epoch - 2ms/step
# Epoch 30/50
# 235/235 - 0s - loss: 0.1030 - accuracy: 0.9599 - val_loss: 0.4049 - val_accuracy: 0.8939 - 427ms/epoch - 2ms/step
# Epoch 31/50
# 235/235 - 0s - loss: 0.0978 - accuracy: 0.9616 - val_loss: 0.4564 - val_accuracy: 0.8967 - 442ms/epoch - 2ms/step
# Epoch 32/50
# 235/235 - 0s - loss: 0.0956 - accuracy: 0.9625 - val_loss: 0.4864 - val_accuracy: 0.8915 - 445ms/epoch - 2ms/step
# Epoch 33/50
# 235/235 - 0s - loss: 0.0952 - accuracy: 0.9626 - val_loss: 0.4916 - val_accuracy: 0.8923 - 437ms/epoch - 2ms/step
# Epoch 34/50
# 235/235 - 0s - loss: 0.0946 - accuracy: 0.9634 - val_loss: 0.4341 - val_accuracy: 0.8965 - 445ms/epoch - 2ms/step
# Epoch 35/50
# 235/235 - 0s - loss: 0.0884 - accuracy: 0.9655 - val_loss: 0.4527 - val_accuracy: 0.8949 - 440ms/epoch - 2ms/step
# Epoch 36/50
# 235/235 - 0s - loss: 0.0891 - accuracy: 0.9658 - val_loss: 0.4998 - val_accuracy: 0.8972 - 434ms/epoch - 2ms/step
# Epoch 37/50
# 235/235 - 0s - loss: 0.0816 - accuracy: 0.9679 - val_loss: 0.4785 - val_accuracy: 0.8920 - 443ms/epoch - 2ms/step
# Epoch 38/50
# 235/235 - 0s - loss: 0.0801 - accuracy: 0.9684 - val_loss: 0.4964 - val_accuracy: 0.8979 - 437ms/epoch - 2ms/step
# Epoch 39/50
# 235/235 - 0s - loss: 0.0745 - accuracy: 0.9706 - val_loss: 0.5020 - val_accuracy: 0.8977 - 438ms/epoch - 2ms/step
# Epoch 40/50
# 235/235 - 0s - loss: 0.0737 - accuracy: 0.9713 - val_loss: 0.5271 - val_accuracy: 0.8941 - 435ms/epoch - 2ms/step
# Epoch 41/50
# 235/235 - 0s - loss: 0.0741 - accuracy: 0.9722 - val_loss: 0.5592 - val_accuracy: 0.8939 - 440ms/epoch - 2ms/step
# Epoch 42/50
# 235/235 - 0s - loss: 0.0673 - accuracy: 0.9737 - val_loss: 0.5674 - val_accuracy: 0.9017 - 440ms/epoch - 2ms/step
# Epoch 43/50
# 235/235 - 0s - loss: 0.0656 - accuracy: 0.9746 - val_loss: 0.6012 - val_accuracy: 0.8946 - 442ms/epoch - 2ms/step
# Epoch 44/50
# 235/235 - 0s - loss: 0.0667 - accuracy: 0.9744 - val_loss: 0.5561 - val_accuracy: 0.8928 - 428ms/epoch - 2ms/step
# Epoch 45/50
# 235/235 - 0s - loss: 0.0572 - accuracy: 0.9782 - val_loss: 0.5860 - val_accuracy: 0.8943 - 437ms/epoch - 2ms/step
# Epoch 46/50
# 235/235 - 0s - loss: 0.0664 - accuracy: 0.9740 - val_loss: 0.5836 - val_accuracy: 0.8981 - 437ms/epoch - 2ms/step
# Epoch 47/50
# 235/235 - 0s - loss: 0.0622 - accuracy: 0.9768 - val_loss: 0.5539 - val_accuracy: 0.8997 - 444ms/epoch - 2ms/step
# Epoch 48/50
# 235/235 - 0s - loss: 0.0577 - accuracy: 0.9787 - val_loss: 0.6022 - val_accuracy: 0.8876 - 438ms/epoch - 2ms/step
# Epoch 49/50
# 235/235 - 0s - loss: 0.0643 - accuracy: 0.9754 - val_loss: 0.5793 - val_accuracy: 0.8995 - 448ms/epoch - 2ms/step
# Epoch 50/50
# 235/235 - 0s - loss: 0.0539 - accuracy: 0.9796 - val_loss: 0.6028 - val_accuracy: 0.8989 - 445ms/epoch - 2ms/step

# %% [markdown]
# Adagrad Model

# %%
dmlp_adagrad = build_model()
dmlp_adagrad.compile(loss='categorical_crossentropy', optimizer=Adagrad(), metrics=['accuracy'])
hist_adagrad = dmlp_adagrad.fit(x_train, y_train, batch_size=batch_size, epochs=n_epoch, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 235/235 - 1s - loss: 2.0016 - accuracy: 0.4145 - val_loss: 1.6543 - val_accuracy: 0.6401 - 1s/epoch - 5ms/step
# Epoch 2/50
# 235/235 - 0s - loss: 1.3201 - accuracy: 0.6627 - val_loss: 1.0817 - val_accuracy: 0.6650 - 435ms/epoch - 2ms/step
# Epoch 3/50
# 235/235 - 0s - loss: 0.9513 - accuracy: 0.6978 - val_loss: 0.8747 - val_accuracy: 0.7046 - 434ms/epoch - 2ms/step
# Epoch 4/50
# 235/235 - 0s - loss: 0.8088 - accuracy: 0.7345 - val_loss: 0.7793 - val_accuracy: 0.7326 - 444ms/epoch - 2ms/step
# Epoch 5/50
# 235/235 - 0s - loss: 0.7323 - accuracy: 0.7584 - val_loss: 0.7193 - val_accuracy: 0.7587 - 426ms/epoch - 2ms/step
# Epoch 6/50
# 235/235 - 0s - loss: 0.6800 - accuracy: 0.7760 - val_loss: 0.6752 - val_accuracy: 0.7720 - 432ms/epoch - 2ms/step
# Epoch 7/50
# 235/235 - 0s - loss: 0.6400 - accuracy: 0.7901 - val_loss: 0.6404 - val_accuracy: 0.7844 - 424ms/epoch - 2ms/step
# Epoch 8/50
# 235/235 - 0s - loss: 0.6080 - accuracy: 0.8001 - val_loss: 0.6129 - val_accuracy: 0.7941 - 423ms/epoch - 2ms/step
# Epoch 9/50
# 235/235 - 0s - loss: 0.5816 - accuracy: 0.8086 - val_loss: 0.5950 - val_accuracy: 0.7982 - 425ms/epoch - 2ms/step
# Epoch 10/50
# 235/235 - 0s - loss: 0.5602 - accuracy: 0.8140 - val_loss: 0.5758 - val_accuracy: 0.8015 - 413ms/epoch - 2ms/step
# Epoch 11/50
# 235/235 - 0s - loss: 0.5422 - accuracy: 0.8187 - val_loss: 0.5552 - val_accuracy: 0.8103 - 429ms/epoch - 2ms/step
# Epoch 12/50
# 235/235 - 0s - loss: 0.5269 - accuracy: 0.8231 - val_loss: 0.5430 - val_accuracy: 0.8133 - 419ms/epoch - 2ms/step
# Epoch 13/50
# 235/235 - 0s - loss: 0.5138 - accuracy: 0.8273 - val_loss: 0.5330 - val_accuracy: 0.8155 - 420ms/epoch - 2ms/step
# Epoch 14/50
# 235/235 - 0s - loss: 0.5028 - accuracy: 0.8304 - val_loss: 0.5243 - val_accuracy: 0.8186 - 412ms/epoch - 2ms/step
# Epoch 15/50
# 235/235 - 0s - loss: 0.4929 - accuracy: 0.8325 - val_loss: 0.5134 - val_accuracy: 0.8218 - 419ms/epoch - 2ms/step
# Epoch 16/50
# 235/235 - 0s - loss: 0.4844 - accuracy: 0.8352 - val_loss: 0.5055 - val_accuracy: 0.8238 - 424ms/epoch - 2ms/step
# Epoch 17/50
# 235/235 - 0s - loss: 0.4766 - accuracy: 0.8370 - val_loss: 0.5029 - val_accuracy: 0.8230 - 416ms/epoch - 2ms/step
# Epoch 18/50
# 235/235 - 0s - loss: 0.4698 - accuracy: 0.8396 - val_loss: 0.4936 - val_accuracy: 0.8294 - 425ms/epoch - 2ms/step
# Epoch 19/50
# 235/235 - 0s - loss: 0.4638 - accuracy: 0.8406 - val_loss: 0.4948 - val_accuracy: 0.8260 - 420ms/epoch - 2ms/step
# Epoch 20/50
# 235/235 - 0s - loss: 0.4579 - accuracy: 0.8429 - val_loss: 0.4819 - val_accuracy: 0.8321 - 418ms/epoch - 2ms/step
# Epoch 21/50
# 235/235 - 0s - loss: 0.4526 - accuracy: 0.8449 - val_loss: 0.4797 - val_accuracy: 0.8307 - 416ms/epoch - 2ms/step
# Epoch 22/50
# 235/235 - 0s - loss: 0.4480 - accuracy: 0.8459 - val_loss: 0.4749 - val_accuracy: 0.8340 - 422ms/epoch - 2ms/step
# Epoch 23/50
# 235/235 - 0s - loss: 0.4435 - accuracy: 0.8472 - val_loss: 0.4751 - val_accuracy: 0.8342 - 417ms/epoch - 2ms/step
# Epoch 24/50
# 235/235 - 0s - loss: 0.4395 - accuracy: 0.8485 - val_loss: 0.4720 - val_accuracy: 0.8323 - 418ms/epoch - 2ms/step
# Epoch 25/50
# 235/235 - 0s - loss: 0.4359 - accuracy: 0.8498 - val_loss: 0.4636 - val_accuracy: 0.8386 - 425ms/epoch - 2ms/step
# Epoch 26/50
# 235/235 - 0s - loss: 0.4316 - accuracy: 0.8509 - val_loss: 0.4619 - val_accuracy: 0.8392 - 423ms/epoch - 2ms/step
# Epoch 27/50
# 235/235 - 0s - loss: 0.4285 - accuracy: 0.8523 - val_loss: 0.4598 - val_accuracy: 0.8378 - 421ms/epoch - 2ms/step
# Epoch 28/50
# 235/235 - 0s - loss: 0.4255 - accuracy: 0.8532 - val_loss: 0.4542 - val_accuracy: 0.8405 - 428ms/epoch - 2ms/step
# Epoch 29/50
# 235/235 - 0s - loss: 0.4219 - accuracy: 0.8547 - val_loss: 0.4551 - val_accuracy: 0.8385 - 420ms/epoch - 2ms/step
# Epoch 30/50
# 235/235 - 0s - loss: 0.4189 - accuracy: 0.8553 - val_loss: 0.4541 - val_accuracy: 0.8378 - 418ms/epoch - 2ms/step
# Epoch 31/50
# 235/235 - 0s - loss: 0.4159 - accuracy: 0.8563 - val_loss: 0.4471 - val_accuracy: 0.8432 - 428ms/epoch - 2ms/step
# Epoch 32/50
# 235/235 - 0s - loss: 0.4135 - accuracy: 0.8572 - val_loss: 0.4458 - val_accuracy: 0.8420 - 409ms/epoch - 2ms/step
# Epoch 33/50
# 235/235 - 0s - loss: 0.4108 - accuracy: 0.8575 - val_loss: 0.4423 - val_accuracy: 0.8438 - 418ms/epoch - 2ms/step
# Epoch 34/50
# 235/235 - 0s - loss: 0.4085 - accuracy: 0.8585 - val_loss: 0.4482 - val_accuracy: 0.8404 - 425ms/epoch - 2ms/step
# Epoch 35/50
# 235/235 - 0s - loss: 0.4058 - accuracy: 0.8598 - val_loss: 0.4474 - val_accuracy: 0.8441 - 433ms/epoch - 2ms/step
# Epoch 36/50
# 235/235 - 0s - loss: 0.4034 - accuracy: 0.8613 - val_loss: 0.4404 - val_accuracy: 0.8450 - 422ms/epoch - 2ms/step
# Epoch 37/50
# 235/235 - 0s - loss: 0.4013 - accuracy: 0.8613 - val_loss: 0.4346 - val_accuracy: 0.8466 - 415ms/epoch - 2ms/step
# Epoch 38/50
# 235/235 - 0s - loss: 0.3992 - accuracy: 0.8623 - val_loss: 0.4370 - val_accuracy: 0.8450 - 415ms/epoch - 2ms/step
# Epoch 39/50
# 235/235 - 0s - loss: 0.3965 - accuracy: 0.8630 - val_loss: 0.4347 - val_accuracy: 0.8471 - 426ms/epoch - 2ms/step
# Epoch 40/50
# 235/235 - 0s - loss: 0.3949 - accuracy: 0.8626 - val_loss: 0.4299 - val_accuracy: 0.8479 - 415ms/epoch - 2ms/step
# Epoch 41/50
# 235/235 - 0s - loss: 0.3928 - accuracy: 0.8640 - val_loss: 0.4297 - val_accuracy: 0.8475 - 407ms/epoch - 2ms/step
# Epoch 42/50
# 235/235 - 0s - loss: 0.3908 - accuracy: 0.8647 - val_loss: 0.4264 - val_accuracy: 0.8501 - 415ms/epoch - 2ms/step
# Epoch 43/50
# 235/235 - 0s - loss: 0.3886 - accuracy: 0.8654 - val_loss: 0.4260 - val_accuracy: 0.8484 - 412ms/epoch - 2ms/step
# Epoch 44/50
# 235/235 - 0s - loss: 0.3875 - accuracy: 0.8658 - val_loss: 0.4223 - val_accuracy: 0.8505 - 431ms/epoch - 2ms/step
# Epoch 45/50
# 235/235 - 0s - loss: 0.3855 - accuracy: 0.8663 - val_loss: 0.4233 - val_accuracy: 0.8512 - 428ms/epoch - 2ms/step
# Epoch 46/50
# 235/235 - 0s - loss: 0.3839 - accuracy: 0.8673 - val_loss: 0.4216 - val_accuracy: 0.8521 - 413ms/epoch - 2ms/step
# Epoch 47/50
# 235/235 - 0s - loss: 0.3822 - accuracy: 0.8675 - val_loss: 0.4208 - val_accuracy: 0.8510 - 412ms/epoch - 2ms/step
# Epoch 48/50
# 235/235 - 0s - loss: 0.3802 - accuracy: 0.8682 - val_loss: 0.4209 - val_accuracy: 0.8525 - 418ms/epoch - 2ms/step
# Epoch 49/50
# 235/235 - 0s - loss: 0.3788 - accuracy: 0.8686 - val_loss: 0.4172 - val_accuracy: 0.8520 - 421ms/epoch - 2ms/step
# Epoch 50/50
# 235/235 - 0s - loss: 0.3771 - accuracy: 0.8696 - val_loss: 0.4143 - val_accuracy: 0.8526 - 413ms/epoch - 2ms/step

# %% [markdown]
# RMSprop Model

# %%
dmlp_rmsprop = build_model()
dmlp_rmsprop.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])
hist_rmsprop = dmlp_rmsprop.fit(x_train, y_train, batch_size=batch_size, epochs=n_epoch, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 235/235 - 1s - loss: 0.7088 - accuracy: 0.7388 - val_loss: 0.5881 - val_accuracy: 0.7915 - 1s/epoch - 5ms/step
# Epoch 2/50
# 235/235 - 0s - loss: 0.4444 - accuracy: 0.8333 - val_loss: 0.4375 - val_accuracy: 0.8339 - 430ms/epoch - 2ms/step
# Epoch 3/50
# 235/235 - 0s - loss: 0.3758 - accuracy: 0.8602 - val_loss: 0.4132 - val_accuracy: 0.8485 - 425ms/epoch - 2ms/step
# Epoch 4/50
# 235/235 - 0s - loss: 0.3397 - accuracy: 0.8726 - val_loss: 0.3692 - val_accuracy: 0.8661 - 422ms/epoch - 2ms/step
# Epoch 5/50
# 235/235 - 0s - loss: 0.3124 - accuracy: 0.8829 - val_loss: 0.4546 - val_accuracy: 0.8390 - 427ms/epoch - 2ms/step
# Epoch 6/50
# 235/235 - 0s - loss: 0.2943 - accuracy: 0.8885 - val_loss: 0.3518 - val_accuracy: 0.8716 - 419ms/epoch - 2ms/step
# Epoch 7/50
# 235/235 - 0s - loss: 0.2777 - accuracy: 0.8939 - val_loss: 0.3597 - val_accuracy: 0.8754 - 421ms/epoch - 2ms/step
# Epoch 8/50
# 235/235 - 0s - loss: 0.2657 - accuracy: 0.8995 - val_loss: 0.3870 - val_accuracy: 0.8588 - 422ms/epoch - 2ms/step
# Epoch 9/50
# 235/235 - 0s - loss: 0.2523 - accuracy: 0.9029 - val_loss: 0.3585 - val_accuracy: 0.8761 - 420ms/epoch - 2ms/step
# Epoch 10/50
# 235/235 - 0s - loss: 0.2412 - accuracy: 0.9071 - val_loss: 0.4212 - val_accuracy: 0.8623 - 422ms/epoch - 2ms/step
# Epoch 11/50
# 235/235 - 0s - loss: 0.2315 - accuracy: 0.9103 - val_loss: 0.3334 - val_accuracy: 0.8860 - 417ms/epoch - 2ms/step
# Epoch 12/50
# 235/235 - 0s - loss: 0.2216 - accuracy: 0.9135 - val_loss: 0.4042 - val_accuracy: 0.8654 - 421ms/epoch - 2ms/step
# Epoch 13/50
# 235/235 - 0s - loss: 0.2136 - accuracy: 0.9173 - val_loss: 0.3502 - val_accuracy: 0.8853 - 423ms/epoch - 2ms/step
# Epoch 14/50
# 235/235 - 0s - loss: 0.2040 - accuracy: 0.9198 - val_loss: 0.3737 - val_accuracy: 0.8807 - 426ms/epoch - 2ms/step
# Epoch 15/50
# 235/235 - 0s - loss: 0.1980 - accuracy: 0.9233 - val_loss: 0.4653 - val_accuracy: 0.8481 - 420ms/epoch - 2ms/step
# Epoch 16/50
# 235/235 - 0s - loss: 0.1901 - accuracy: 0.9254 - val_loss: 0.3954 - val_accuracy: 0.8849 - 429ms/epoch - 2ms/step
# Epoch 17/50
# 235/235 - 0s - loss: 0.1829 - accuracy: 0.9290 - val_loss: 0.3743 - val_accuracy: 0.8903 - 410ms/epoch - 2ms/step
# Epoch 18/50
# 235/235 - 0s - loss: 0.1785 - accuracy: 0.9306 - val_loss: 0.3985 - val_accuracy: 0.8791 - 427ms/epoch - 2ms/step
# Epoch 19/50
# 235/235 - 0s - loss: 0.1715 - accuracy: 0.9323 - val_loss: 0.4133 - val_accuracy: 0.8841 - 419ms/epoch - 2ms/step
# Epoch 20/50
# 235/235 - 0s - loss: 0.1653 - accuracy: 0.9341 - val_loss: 0.4141 - val_accuracy: 0.8886 - 421ms/epoch - 2ms/step
# Epoch 21/50
# 235/235 - 0s - loss: 0.1601 - accuracy: 0.9370 - val_loss: 0.4199 - val_accuracy: 0.8884 - 422ms/epoch - 2ms/step
# Epoch 22/50
# 235/235 - 0s - loss: 0.1550 - accuracy: 0.9386 - val_loss: 0.3803 - val_accuracy: 0.8999 - 422ms/epoch - 2ms/step
# Epoch 23/50
# 235/235 - 0s - loss: 0.1505 - accuracy: 0.9412 - val_loss: 0.4158 - val_accuracy: 0.8892 - 416ms/epoch - 2ms/step
# Epoch 24/50
# 235/235 - 0s - loss: 0.1451 - accuracy: 0.9420 - val_loss: 0.4150 - val_accuracy: 0.8914 - 415ms/epoch - 2ms/step
# Epoch 25/50
# 235/235 - 0s - loss: 0.1401 - accuracy: 0.9446 - val_loss: 0.4582 - val_accuracy: 0.8911 - 410ms/epoch - 2ms/step
# Epoch 26/50
# 235/235 - 0s - loss: 0.1388 - accuracy: 0.9453 - val_loss: 0.4908 - val_accuracy: 0.8739 - 417ms/epoch - 2ms/step
# Epoch 27/50
# 235/235 - 0s - loss: 0.1328 - accuracy: 0.9486 - val_loss: 0.4670 - val_accuracy: 0.8861 - 413ms/epoch - 2ms/step
# Epoch 28/50
# 235/235 - 0s - loss: 0.1338 - accuracy: 0.9469 - val_loss: 0.4530 - val_accuracy: 0.8810 - 428ms/epoch - 2ms/step
# Epoch 29/50
# 235/235 - 0s - loss: 0.1291 - accuracy: 0.9500 - val_loss: 0.5963 - val_accuracy: 0.8715 - 418ms/epoch - 2ms/step
# Epoch 30/50
# 235/235 - 0s - loss: 0.1244 - accuracy: 0.9512 - val_loss: 0.6617 - val_accuracy: 0.8844 - 410ms/epoch - 2ms/step
# Epoch 31/50
# 235/235 - 0s - loss: 0.1215 - accuracy: 0.9529 - val_loss: 0.5535 - val_accuracy: 0.8896 - 413ms/epoch - 2ms/step
# Epoch 32/50
# 235/235 - 0s - loss: 0.1179 - accuracy: 0.9536 - val_loss: 0.4998 - val_accuracy: 0.9008 - 433ms/epoch - 2ms/step
# Epoch 33/50
# 235/235 - 0s - loss: 0.1158 - accuracy: 0.9550 - val_loss: 0.5610 - val_accuracy: 0.8970 - 416ms/epoch - 2ms/step
# Epoch 34/50
# 235/235 - 0s - loss: 0.1124 - accuracy: 0.9564 - val_loss: 0.5065 - val_accuracy: 0.8825 - 425ms/epoch - 2ms/step
# Epoch 35/50
# 235/235 - 0s - loss: 0.1096 - accuracy: 0.9575 - val_loss: 0.5318 - val_accuracy: 0.8857 - 406ms/epoch - 2ms/step
# Epoch 36/50
# 235/235 - 0s - loss: 0.1090 - accuracy: 0.9573 - val_loss: 0.5399 - val_accuracy: 0.8875 - 434ms/epoch - 2ms/step
# Epoch 37/50
# 235/235 - 0s - loss: 0.1055 - accuracy: 0.9594 - val_loss: 0.4972 - val_accuracy: 0.8896 - 415ms/epoch - 2ms/step
# Epoch 38/50
# 235/235 - 0s - loss: 0.1036 - accuracy: 0.9607 - val_loss: 0.6211 - val_accuracy: 0.8900 - 456ms/epoch - 2ms/step
# Epoch 39/50
# 235/235 - 0s - loss: 0.0987 - accuracy: 0.9616 - val_loss: 0.5986 - val_accuracy: 0.8953 - 411ms/epoch - 2ms/step
# Epoch 40/50
# 235/235 - 0s - loss: 0.0985 - accuracy: 0.9621 - val_loss: 0.6150 - val_accuracy: 0.8967 - 431ms/epoch - 2ms/step
# Epoch 41/50
# 235/235 - 0s - loss: 0.0963 - accuracy: 0.9632 - val_loss: 0.6478 - val_accuracy: 0.8963 - 425ms/epoch - 2ms/step
# Epoch 42/50
# 235/235 - 0s - loss: 0.0969 - accuracy: 0.9634 - val_loss: 0.6308 - val_accuracy: 0.8796 - 416ms/epoch - 2ms/step
# Epoch 43/50
# 235/235 - 0s - loss: 0.0942 - accuracy: 0.9653 - val_loss: 0.6241 - val_accuracy: 0.8935 - 419ms/epoch - 2ms/step
# Epoch 44/50
# 235/235 - 0s - loss: 0.0919 - accuracy: 0.9653 - val_loss: 0.6515 - val_accuracy: 0.8927 - 423ms/epoch - 2ms/step
# Epoch 45/50
# 235/235 - 0s - loss: 0.0904 - accuracy: 0.9661 - val_loss: 0.7122 - val_accuracy: 0.8862 - 430ms/epoch - 2ms/step
# Epoch 46/50
# 235/235 - 0s - loss: 0.0907 - accuracy: 0.9657 - val_loss: 0.7426 - val_accuracy: 0.8968 - 423ms/epoch - 2ms/step
# Epoch 47/50
# 235/235 - 0s - loss: 0.0893 - accuracy: 0.9661 - val_loss: 0.8878 - val_accuracy: 0.8804 - 432ms/epoch - 2ms/step
# Epoch 48/50
# 235/235 - 0s - loss: 0.0886 - accuracy: 0.9674 - val_loss: 0.6787 - val_accuracy: 0.8918 - 416ms/epoch - 2ms/step
# Epoch 49/50
# 235/235 - 0s - loss: 0.0863 - accuracy: 0.9675 - val_loss: 0.7654 - val_accuracy: 0.8880 - 432ms/epoch - 2ms/step
# Epoch 50/50
# 235/235 - 0s - loss: 0.0887 - accuracy: 0.9676 - val_loss: 0.6572 - val_accuracy: 0.8873 - 425ms/epoch - 2ms/step

# %% [markdown]
# #### print all of their accuracies

# %%
print(f"SGD Acc: {dmlp_sgd.evaluate(x_test, y_test, verbose=0)[1]*100}")
print(f"Adam Acc: {dmlp_adam.evaluate(x_test, y_test, verbose=0)[1]*100}")
print(f"Adagrad Acc: {dmlp_adagrad.evaluate(x_test, y_test, verbose=0)[1]*100}")
print(f"RMSprop Acc: {dmlp_rmsprop.evaluate(x_test, y_test, verbose=0)[1]*100}")
# Out:
# SGD Acc: 87.81999945640564
# Adam Acc: 89.88999724388123
# Adagrad Acc: 85.25999784469604
# RMSprop Acc: 88.73000144958496

# %% [markdown]
# #### Accuracy visualization

# %%
import matplotlib.pyplot as plt

plt.plot(hist_sgd.history['accuracy'], 'r')
plt.plot(hist_sgd.history['val_accuracy'], 'r--')
plt.plot(hist_adam.history['accuracy'], 'g')
plt.plot(hist_adam.history['val_accuracy'], 'g--')
plt.plot(hist_adagrad.history['accuracy'], 'b')
plt.plot(hist_adagrad.history['val_accuracy'], 'b--')
plt.plot(hist_rmsprop.history['accuracy'], 'm')
plt.plot(hist_rmsprop.history['val_accuracy'], 'm--')

plt.title('Model accuracy comparison between optimizers')
plt.ylim(0.6, 1.0)
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train_sgd', 'Val_sgd', 'Train_adam', 'Val_adam', 'Train_adagrad', 'Val_adagrad', 'Train_rmsprop', 'Val_rmsprop'], loc='best')
plt.grid()
plt.show()

# %% [markdown]
# ### Test result
#
# Adam > RMSprop > SGD > Adagrad

# %% [markdown]
# * SGD: Using small learning rate.
# * Adagrad: Setting learning rate using accumulated information from previous gradient.
# * RMSprop: Improving Adagrad by removing effects from old information when accumulating previous gradient.
# * Adam: Improving RMSprop by applying momentum to it.
